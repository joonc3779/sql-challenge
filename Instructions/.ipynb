# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import matplotlib.pyplot as plt
from databaseconfig import user_name, password, local_host

# I am pretty sure I set up my sql by setting local host, database, port, and username but I keep getting the error databaseconfig.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-c40c0be8257d> in <module>
#       4 import psycopg2
#       5 import matplotlib.pyplot as plt
# ----> 6 from databaseconfig import user_name, password, local_host
#
# ModuleNotFoundError: No module named 'databaseconfig'

# %%
# Connect to postgres
engine = create_engine(f'postgresql://{user_name}:{password}@{local_host}/sql-challenge')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6153776f6156> in <module>
#       1 # Connect to postgres
# ----> 2 engine = create_engine(f'postgresql://{user_name}:{password}@{local_host}/sql-challenge')
#       3 connection = engine.connect()
#
# NameError: name 'user_name' is not defined

# %%
# Create DataFrame based on SQL Titles table
query = 'select * from titles'
df_titles = pd.read_sql_query(query, con=engine)
df_titles.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d46b3ceb7081> in <module>
#       1 # Create DataFrame based on SQL Titles table
#       2 query = 'select * from titles'
# ----> 3 df_titles = pd.read_sql_query(query, con=engine)
#       4 df_titles.head()
#
# NameError: name 'engine' is not defined

# %%
# Create DataFrame based on SQL Salaries table
query = 'select * from salaries'
df_salaries = pd.read_sql_query(query, con=engine)
df_salaries.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d9605df010fd> in <module>
#       1 # Create DataFrame based on SQL Salaries table
#       2 query = 'select * from salaries'
# ----> 3 df_salaries = pd.read_sql_query(query, con=engine)
#       4 df_salaries.head()
#
# NameError: name 'engine' is not defined

# %%
# Merge the titles and salaries DataFrames
merged = pd.merge(df_titles,df_salaries,on='emp_no')
merged.head()

# %%
# Clean up merged DataFrame
merged_drop = merged.drop(columns =['emp_no','from_date_x','to_date_x','from_date_y','to_date_y'])

# Find the average salary by job title
grouped_df = merged_drop.groupby('title').mean()
grouped_formatted = grouped_df.copy()

grouped_formatted['salary'] = grouped_formatted['salary'].map('${:,.2f}'.format)
grouped_formatted

# %%
# Plot the average salary by job title
plt.figure(figsize=(10,6))
plt.bar(grouped_df.index,grouped_df['salary'])
plt.xlabel('Job Title')
plt.ylabel('Average Salary ($)')
plt.title('Average Salary by Job Title',size=13)
plt.grid()
plt.savefig('Images/AvgSalarybyTitle.png')

# %%
# Dispose of engine
engine.dispose()
